# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Load the data
data = pd.read_csv("D:\\Machine learning\\DataSets\\Salaries.csv")
# Out:
# C:\Users\Abdullah khan\AppData\Local\Temp\ipykernel_2828\2898218916.py:2: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("D:\\Machine learning\\DataSets\\Salaries.csv")

# %%
# Take the sample from data how it looks like
data.sample(3)
# Out:
#             Id       EmployeeName                    JobTitle   BasePay  \
# 58698    58699         Connie Dao                   Custodian   51492.8
# 93491    93492  Rochelle  Feldman                  Unit Clerk  63292.72
# 118340  118341  Andrea C Canziani  Protective Services Worker   94691.0
#
#        OvertimePay OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 58698      2573.61  4402.32  27726.94   58468.73          86195.67  2012
# 93491          0.0  4392.16  26917.69   67684.88          94602.57  2013
# 118340    21688.82  2590.77   34986.4  118970.59         153956.99  2014
#
#         Notes         Agency Status
# 58698     NaN  San Francisco    NaN
# 93491     NaN  San Francisco    NaN
# 118340    NaN  San Francisco     FT

# %%
# Top 10 rows
data.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %%
# bottom 10 rows
data.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant             0
# 148645  148646  Carolyn A Wilson     Human Services Technician             0
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2             0
# 148648  148649       Leon Walker                     Custodian             0
# 148649  148650     Roy I Tillery                     Custodian             0
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654      Not provided    Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
# Data types
data.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %%
# find the shape of our dataset(number of rows and columns)
data.shape
print(f"Number of rows: {data.shape[0]} and number of columns are: {data.shape[1]}")
# Out:
# Number of rows: 148654 and number of columns are: 13

# %%
# Getting inforamtion about dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
# Check Null values in the Dataset
data.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
# Drop ID,Notes,Agency and status columns
data.drop(["Id","Agency","Status"], axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %%
# Get overall statistics about the dataframe
data.describe()
data.describe(include="all")
# Out:
#                    Id EmployeeName          JobTitle   BasePay  OvertimePay  \
# count   148654.000000       148654            148654  148049.0     148654.0
# unique            NaN       110810              2159  109900.0      66555.0
# top               NaN    Kevin Lee  Transit Operator       0.0          0.0
# freq              NaN           13              7036     875.0      66103.0
# mean     74327.500000          NaN               NaN       NaN          NaN
# std      42912.857795          NaN               NaN       NaN          NaN
# min          1.000000          NaN               NaN       NaN          NaN
# 25%      37164.250000          NaN               NaN       NaN          NaN
# 50%      74327.500000          NaN               NaN       NaN          NaN
# 75%     111490.750000          NaN               NaN       NaN          NaN
# max     148654.000000          NaN               NaN       NaN          NaN
#
# ...

# %%
# Find the occurence of employee name
data["EmployeeName"].value_counts().head(5)
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# William Wong    11
# Steven Lee      11
# Stanley Lee      9
# Name: count, dtype: int64

# %%
# Find the number of unique job titles
data["JobTitle"].nunique()
# Out:
# 2159

# %%
# Total number of Job titles contain Captain
data[data["JobTitle"].str.contains("Captain", case=False)].count()
# Out:
# Id                  552
# EmployeeName        552
# JobTitle            552
# BasePay             551
# OvertimePay         552
# OtherPay            552
# Benefits            411
# TotalPay            552
# TotalPayBenefits    552
# Year                552
# Notes                 0
# Agency              552
# Status              141
# dtype: int64

# %%
# All The employees name from the fire department
data[data["JobTitle"].str.contains("FIRE", case=False)]["EmployeeName"]
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %%
# Find the minimum, maximum and average pay
data["BasePay"].describe()
# Out:
# count     148049.0
# unique    109900.0
# top            0.0
# freq         875.0
# Name: BasePay, dtype: float64

# %%
# Replace the "Not Provided" in EmployeeName column to NaN
data[data["EmployeeName"].str.contains("Not provided")]
data.loc[[148646,148650,148651,148652],["EmployeeName"]] = np.nan
data["EmployeeName"].replace(np.nan, np.nan)
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653         Not provided
# Name: EmployeeName, Length: 148654, dtype: object

# %%
# Replace the "Not Provided" in EmployeeName column to NaN
# data[data["EmployeeName"].str.contains("Not provided")]
data["EmployeeName"].replace("Not provided", np.nan)
data["EmployeeName"] = data["EmployeeName"].replace("Not provided", np.nan) # for storing permanent

# %%
# Drop the rows having 5 missing values
data[data.isnull().sum(axis=1) == 5]
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
# Inplace is used for premanent store data 
data["JobTitle"] = data["JobTitle"].replace("Not provided", np.nan)
data["BasePay"] = data["BasePay"].replace("Not provided", np.nan)
data["OvertimePay"] = data["OvertimePay"].replace("Not provided", np.nan)
data["OtherPay"] = data["OtherPay"].replace("Not provided", np.nan)
data["Benefits"] = data["Benefits"].replace("Not provided", np.nan)

# %%
columns_to_replce = ["JobTitle","BasePay","OvertimePay","OtherPay","Benefits"]
data[columns_to_replce] = data[columns_to_replce].replace("Not provided",np.nan)
data.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant             0
# 148645  148646  Carolyn A Wilson     Human Services Technician             0
# 148646  148647               NaN                           NaN  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2             0
# 148648  148649       Leon Walker                     Custodian             0
# 148649  148650     Roy I Tillery                     Custodian             0
# 148650  148651               NaN                           NaN  Not Provided
# 148651  148652               NaN                           NaN  Not Provided
# 148652  148653               NaN                           NaN  Not Provided
# 148653  148654               NaN    Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
# Find the job title of Joann Anderson
# data[data["EmployeeName"].str.contains("Joann Anderson")]["JobTitle"]

# OR

data[data["EmployeeName"] == "Joann Anderson"]["JobTitle"]
# Out:
# 53817     Communications Dispatcher 2
# 148647    Communications Dispatcher 2
# Name: JobTitle, dtype: object

# %%
# How much Joann Anderson make with benifits
data[data["EmployeeName"] == "Joann Anderson"]["TotalPayBenefits"]
# Out:
# 53817     104133.22
# 148647         0.00
# Name: TotalPayBenefits, dtype: float64

# %%
# Name of the person having the Highest Basepay
data["BasePay"].replace("Not provided", np.nan, inplace=True)
# Out:
# C:\Users\Abdullah khan\AppData\Local\Temp\ipykernel_2828\1784058440.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["BasePay"].replace("Not provided", np.nan, inplace=True)

# %%
data[data["BasePay"] == "Not Provided"]
data["BasePay"] = data["BasePay"].replace( to_replace="Not Provided", value = np.nan)

# %%
data["BasePay"] = pd.to_numeric(data["BasePay"])
data[data["BasePay"].max() == data["BasePay"]]["EmployeeName"]
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %%
# Find the average basepasy of All employee per year
# data["BasePay"]
data.groupby("Year")["BasePay"].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
# Find the Average BasePay of ALL Employee per JobTitle
data.groupby("JobTitle")["BasePay"].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2158, dtype: float64

# %%
# Find the Average BasePay of Employee Having job title ACCOUNTANT
# data[data["JobTitle"].str.contains("ACCOUNTANT", case=False)]["BasePay"].mean()
data[data["JobTitle"] == "ACCOUNTANT"]["BasePay"].mean()
# Out:
# np.float64(46643.172)

# %%
# Find top 5 most common jobs
data["JobTitle"].value_counts().head(5)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.barplot(data["JobTitle"].value_counts().head(5))
# Out:
# <Axes: xlabel='JobTitle', ylabel='count'>

# %%
data.sample()
# Out:
#           Id         EmployeeName       JobTitle  BasePay OvertimePay  \
# 96293  96294  Mariabene G Salarda  Special Nurse  67389.5      989.85
#
#       OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 96293  6279.96  10480.34  74659.31          85139.65  2013    NaN
#
#               Agency Status
# 96293  San Francisco    NaN

# %%
# Find the average basepasy of All employee per year (Graph)
sns.barplot(data.groupby("Year")["BasePay"].mean())
# Out:
# <Axes: xlabel='Year', ylabel='BasePay'>
